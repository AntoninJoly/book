# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import sys
sys.path.append('../../src/book_spine')
from process_dataset import process_json_to_img

data_dir = '../data'

# %% [markdown]
# # Extract image information and create visualization

# %%
img = process_json_to_img(data_dir, seed=0)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 661/661 [54:56<00:00,  4.99s/it]

# %% [markdown]
# # Few examples

# %%
display = 6

plt.figure(figsize=(20,10))
for idx, path in enumerate(img_paths[:display]):
    img = cv2.imread(path)
    plt.subplot(2,3,idx+1)
    plt.imshow(img)
    plt.axis('off')
