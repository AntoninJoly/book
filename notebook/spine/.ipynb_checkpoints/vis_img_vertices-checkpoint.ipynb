# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import sys
sys.path.append('../../src/spine/dataset')
from process_dataset import process_json_to_img

data_dir = '../../data/spine'

# %% [markdown]
# # Extract image information and create visualization

# %%
plt.figure(figsize=(20,20))

for idx in range(6):
    vis, img, vrt = process_json_to_img(data_dir, seed=idx)
    plt.subplot(3,2,idx+1)
    plt.imshow(vis)
    plt.axis('off')
plt.tight_layout()
